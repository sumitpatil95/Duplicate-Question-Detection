# %%
# ==========================================================
# 🚀 STEP 1: INSTALL DEPENDENCIES
# ==========================================================
# !pip install streamlit pyngrok fuzzywuzzy python-Levenshtein bs4 distance

# ==========================================================
# 🚀 STEP 2: IMPORT REQUIRED TOOLS
# ==========================================================
from pyngrok import ngrok
import shutil
from google.colab import files

# Kill any old tunnels (avoid duplicates)
ngrok.kill()

print("✅ Environment ready.")

# ==========================================================
# 🚀 STEP 3: UPLOAD PROJECT FILES
# ==========================================================
# 👉 Upload the following files when prompted:
#     - app.py
#     - helper.py
#     - model.pkl
#     - cv.pkl
#     - stopwords.pkl
uploaded = files.upload()

# Move uploaded files into working directory
for fn in uploaded.keys():
    shutil.move(fn, f"./{fn}")

print("✅ Files uploaded successfully.")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 72.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.3/153.3 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 73.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 76.9 MB/s eta 0:00:00
# ...
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16256 sha256=5da6994e7d62126d4cca25583b43b920ca525fdd729eba94dd24b374903b8e9e
#   Stored in directory: /root/.cache/pip/wheels/24/a8/58/407063d8e5c1d4dd6594c99d12baa0108570b56a92325587dd
# Successfully built distance
# ...
# ✅ Environment ready.
#      <input type="file" id="files-546b7759-43c5-4a2f-98ec-0a0dc271f743" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-546b7759-43c5-4a2f-98ec-0a0dc271f743">
# ...

# %%
# !pip install scikit-learn==1.2.2
